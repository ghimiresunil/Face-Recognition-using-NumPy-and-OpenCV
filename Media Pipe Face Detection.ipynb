# %%
import cv2
import mediapipe as mp
import time

# %%
mp_facedetector = mp.solutions.face_detection
mp_draw = mp.solutions.drawing_utils

# %%
cap = cv2.VideoCapture(-1)

with mp_facedetector.FaceDetection(min_detection_confidence=0.7) as face_detection:
    while cap.isOpened():
        success, image = cap.read()
        start = time.time()
        # Convert the BGR image to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        # Process the image and find faces
        results = face_detection.process(image)
        # Convert the image color back so it can be displayed
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.detections:
            for id, detection in enumerate(results.detections):
                mp_draw.draw_detection(image, detection)
                print(id, detection)
                bBox = detection.location_data.relative_bounding_box
                h, w, c = image.shape
                boundBox = int(bBox.xmin * w), int(bBox.ymin * h), int(bBox.width * w), int(bBox.height * h)
                cv2.putText(image, f'Detected Face:{int(detection.score[0]*100)}%', (boundBox[0], boundBox[1] - 20), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,255,0), 2)
        end = time.time()
        totalTime = end - start
        fps = 1 / totalTime
        print("FPS: ", fps)
        cv2.putText(image, f'FPS: {int(fps)}', (20,70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
        cv2.imshow('Face Detection', image)
        cv2.imwrite('final_sunil.jpg', image)
        if cv2.waitKey(5) & 0xFF == ord("q"):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0 label_id: 0
# score: 0.8445307016372681
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5075781345367432
#     ymin: 0.4774954915046692
#     width: 0.3711709976196289
#     height: 0.4948117733001709
#   }
#   relative_keypoints {
#     x: 0.6721199750900269
#     y: 0.5945197939872742
#   }
#   relative_keypoints {
#     x: 0.8290625810623169
#     y: 0.6141011118888855
#   }
#   relative_keypoints {
#     x: 0.7867258787155151
#     y: 0.711332380771637
#   }
#   relative_keypoints {
#     x: 0.7602983713150024
#     y: 0.8250426650047302
#   }
#   relative_keypoints {
#     x: 0.5116786956787109
#     y: 0.6413130760192871
#   }
#   relative_keypoints {
#     x: 0.8450595140457153
#     y: 0.6716057658195496
#   }
# }
#
# FPS:  103.374180509686
# 0 label_id: 0
# score: 0.8511602282524109
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5087093114852905
#     ymin: 0.4847860336303711
#     width: 0.37085580825805664
#     height: 0.49438923597335815
#   }
#   relative_keypoints {
#     x: 0.6794441938400269
#     y: 0.5991215705871582
#   }
#   relative_keypoints {
#     x: 0.8355978727340698
#     y: 0.6245802044868469
#   }
#   relative_keypoints {
#     x: 0.7951313853263855
#     y: 0.7176433205604553
#   }
#   relative_keypoints {
#     x: 0.7651990652084351
#     y: 0.8311319351196289
#   }
#   relative_keypoints {
#     x: 0.5125616788864136
#     y: 0.6428704261779785
#   }
#   relative_keypoints {
#     x: 0.8455129861831665
#     y: 0.6843400001525879
#   }
# }
#
# FPS:  99.7503805175038
# 0 label_id: 0
# score: 0.8518729209899902
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5119430422782898
#     ymin: 0.48402613401412964
#     width: 0.36716699600219727
#     height: 0.48947417736053467
#   }
#   relative_keypoints {
#     x: 0.6817584037780762
#     y: 0.6089622974395752
#   }
#   relative_keypoints {
#     x: 0.8331029415130615
#     y: 0.6227208971977234
#   }
#   relative_keypoints {
#     x: 0.7986884713172913
#     y: 0.726609468460083
#   }
#   relative_keypoints {
#     x: 0.7716505527496338
#     y: 0.8340931534767151
#   }
#   relative_keypoints {
#     x: 0.517535924911499
#     y: 0.6510696411132812
#   }
#   relative_keypoints {
#     x: 0.8423069715499878
#     y: 0.6718065142631531
#   }
# }
#
# FPS:  96.90194991220774
# 0 label_id: 0
# score: 0.8652196526527405
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5137332677841187
#     ymin: 0.47304654121398926
#     width: 0.3629090189933777
#     height: 0.48384732007980347
#   }
#   relative_keypoints {
#     x: 0.6917763948440552
#     y: 0.6027371883392334
#   }
#   relative_keypoints {
#     x: 0.8358585834503174
#     y: 0.6282424926757812
#   }
#   relative_keypoints {
#     x: 0.7979094386100769
#     y: 0.7327733635902405
#   }
#   relative_keypoints {
#     x: 0.762125551700592
#     y: 0.8307382464408875
#   }
#   relative_keypoints {
#     x: 0.5177111625671387
#     y: 0.6115034222602844
#   }
#   relative_keypoints {
#     x: 0.8345111608505249
#     y: 0.6633204817771912
#   }
# }
#
# FPS:  99.1866058126611
# 0 label_id: 0
# score: 0.8613473773002625
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.51044100522995
#     ymin: 0.478432834148407
#     width: 0.3644844889640808
#     height: 0.4859358072280884
#   }
#   relative_keypoints {
#     x: 0.6945677995681763
#     y: 0.6088947653770447
#   }
#   relative_keypoints {
#     x: 0.8369922041893005
#     y: 0.6317348480224609
#   }
#   relative_keypoints {
#     x: 0.806833028793335
#     y: 0.7377798557281494
#   }
#   relative_keypoints {
#     x: 0.7712342739105225
#     y: 0.8369243741035461
#   }
#   relative_keypoints {
#     x: 0.5151504874229431
#     y: 0.6238307356834412
#   }
#   relative_keypoints {
#     x: 0.8296294212341309
#     y: 0.66656893491745
#   }
# }
#
# FPS:  89.79071758862818
# 0 label_id: 0
# score: 0.8718019127845764
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5114448666572571
#     ymin: 0.48405832052230835
#     width: 0.3720961809158325
#     height: 0.4960523843765259
#   }
#   relative_keypoints {
#     x: 0.6901808977127075
#     y: 0.6145874857902527
#   }
#   relative_keypoints {
#     x: 0.843293309211731
#     y: 0.6298243999481201
#   }
#   relative_keypoints {
#     x: 0.8116363286972046
#     y: 0.7406783103942871
#   }
#   relative_keypoints {
#     x: 0.7814671397209167
#     y: 0.8452430367469788
#   }
#   relative_keypoints {
#     x: 0.5147361755371094
#     y: 0.6455613970756531
#   }
#   relative_keypoints {
#     x: 0.8464248180389404
#     y: 0.6710147261619568
#   }
# }
#
# FPS:  102.14314589776684
# 0 label_id: 0
# score: 0.8545256853103638
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5067066550254822
#     ymin: 0.4825018644332886
#     width: 0.37300848960876465
#     height: 0.4972638487815857
#   }
#   relative_keypoints {
#     x: 0.6954624652862549
#     y: 0.6106226444244385
#   }
#   relative_keypoints {
#     x: 0.8400263786315918
#     y: 0.6349754929542542
#   }
#   relative_keypoints {
#     x: 0.8122331500053406
#     y: 0.7449164986610413
#   }
#   relative_keypoints {
#     x: 0.7775878310203552
#     y: 0.8482977747917175
#   }
#   relative_keypoints {
#     x: 0.5179946422576904
#     y: 0.6315628886222839
#   }
#   relative_keypoints {
#     x: 0.8333070874214172
#     y: 0.6747706532478333
#   }
# }
#
# FPS:  94.47268959614388
# 0 label_id: 0
# score: 0.8434242606163025
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5108935832977295
#     ymin: 0.4854186177253723
#     width: 0.37040209770202637
#     height: 0.4937870502471924
#   }
#   relative_keypoints {
#     x: 0.6963183879852295
#     y: 0.6172199249267578
#   }
#   relative_keypoints {
#     x: 0.8391605019569397
#     y: 0.6357792019844055
#   }
#   relative_keypoints {
#     x: 0.8129000067710876
#     y: 0.7501556873321533
#   }
#   relative_keypoints {
#     x: 0.7804967164993286
#     y: 0.8513069748878479
#   }
#   relative_keypoints {
#     x: 0.5221312046051025
#     y: 0.6374337673187256
#   }
#   relative_keypoints {
#     x: 0.8344401121139526
#     y: 0.6700447201728821
#   }
# }
#
# FPS:  94.93241591598388
# 0 label_id: 0
# score: 0.8886528015136719
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5125678777694702
#     ymin: 0.4827864170074463
#     width: 0.38058918714523315
#     height: 0.507377564907074
#   }
#   relative_keypoints {
#     x: 0.7156007289886475
#     y: 0.6202414035797119
#   }
#   relative_keypoints {
#     x: 0.8546639680862427
#     y: 0.6471291184425354
#   }
#   relative_keypoints {
#     x: 0.8339564800262451
#     y: 0.758660614490509
#   }
#   relative_keypoints {
#     x: 0.7966585159301758
#     y: 0.8589234948158264
#   }
#   relative_keypoints {
#     x: 0.5302311778068542
#     y: 0.6358363032341003
#   }
#   relative_keypoints {
#     x: 0.8369148373603821
#     y: 0.6832570433616638
#   }
# }
#
# FPS:  99.17722446856305
# 0 label_id: 0
# score: 0.8903636932373047
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5100746750831604
#     ymin: 0.47905319929122925
#     width: 0.3808252811431885
#     height: 0.5076911449432373
#   }
#   relative_keypoints {
#     x: 0.7077621817588806
#     y: 0.6135461330413818
#   }
#   relative_keypoints {
#     x: 0.8501756191253662
#     y: 0.64347904920578
#   }
#   relative_keypoints {
#     x: 0.8230842351913452
#     y: 0.753757655620575
#   }
#   relative_keypoints {
#     x: 0.7864383459091187
#     y: 0.854229748249054
#   }
#   relative_keypoints {
#     x: 0.5263020992279053
#     y: 0.6281866431236267
#   }
#   relative_keypoints {
#     x: 0.8388705253601074
#     y: 0.6818571090698242
#   }
# }
#
# FPS:  98.49483374037197
# 0 label_id: 0
# score: 0.9004758596420288
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5192047357559204
#     ymin: 0.4798402190208435
#     width: 0.37505871057510376
#     height: 0.5000022649765015
#   }
#   relative_keypoints {
#     x: 0.7169970870018005
#     y: 0.6190714836120605
#   }
#   relative_keypoints {
#     x: 0.8541593551635742
#     y: 0.646732747554779
#   }
#   relative_keypoints {
#     x: 0.8305351734161377
#     y: 0.7586407661437988
#   }
#   relative_keypoints {
#     x: 0.7940824627876282
#     y: 0.8529275059700012
#   }
#   relative_keypoints {
#     x: 0.5373233556747437
#     y: 0.6280543804168701
#   }
#   relative_keypoints {
#     x: 0.8405370712280273
#     y: 0.677790105342865
#   }
# }
#
# FPS:  103.47874571336935
# 0 label_id: 0
# score: 0.9001027941703796
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5189061760902405
#     ymin: 0.48395591974258423
#     width: 0.37423819303512573
#     height: 0.49890804290771484
#   }
#   relative_keypoints {
#     x: 0.7171720862388611
#     y: 0.621931254863739
#   }
#   relative_keypoints {
#     x: 0.8516373038291931
#     y: 0.6503319144248962
#   }
#   relative_keypoints {
#     x: 0.8283469080924988
#     y: 0.7621353268623352
#   }
#   relative_keypoints {
#     x: 0.791405975818634
#     y: 0.8566777110099792
#   }
#   relative_keypoints {
#     x: 0.5390777587890625
#     y: 0.6294789910316467
#   }
#   relative_keypoints {
#     x: 0.8368174433708191
#     y: 0.681555449962616
#   }
# }
#
# FPS:  99.99771123402633
# 0 label_id: 0
# score: 0.9203191995620728
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5212545394897461
#     ymin: 0.4811134338378906
#     width: 0.3738390803337097
#     height: 0.49837666749954224
#   }
#   relative_keypoints {
#     x: 0.7253037095069885
#     y: 0.6232345700263977
#   }
#   relative_keypoints {
#     x: 0.8552652597427368
#     y: 0.6569359302520752
#   }
#   relative_keypoints {
#     x: 0.8338163495063782
#     y: 0.7701433300971985
#   }
#   relative_keypoints {
#     x: 0.7939086556434631
#     y: 0.8588531613349915
#   }
#   relative_keypoints {
#     x: 0.5456015467643738
#     y: 0.6212409138679504
#   }
#   relative_keypoints {
#     x: 0.8350104689598083
#     y: 0.6842482686042786
#   }
# }
#
# FPS:  77.37568948659768
# 0 label_id: 0
# score: 0.9156443476676941
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5182803869247437
#     ymin: 0.47968536615371704
#     width: 0.3730658292770386
#     height: 0.49734508991241455
#   }
#   relative_keypoints {
#     x: 0.7155185341835022
#     y: 0.6169271469116211
#   }
#   relative_keypoints {
#     x: 0.8507195115089417
#     y: 0.6440649628639221
#   }
#   relative_keypoints {
#     x: 0.8280211687088013
#     y: 0.7546665072441101
#   }
#   relative_keypoints {
#     x: 0.7918476462364197
#     y: 0.8492496609687805
#   }
#   relative_keypoints {
#     x: 0.5380181074142456
#     y: 0.6288120150566101
#   }
#   relative_keypoints {
#     x: 0.8372824788093567
#     y: 0.6775724291801453
#   }
# }
#
# FPS:  106.32488339079295
# 0 label_id: 0
# score: 0.91703200340271
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5170888900756836
#     ymin: 0.4866027235984802
#     width: 0.3725968599319458
#     height: 0.49672114849090576
#   }
#   relative_keypoints {
#     x: 0.7172743678092957
#     y: 0.6230428814888
#   }
#   relative_keypoints {
#     x: 0.8499217629432678
#     y: 0.6535205245018005
#   }
#   relative_keypoints {
#     x: 0.8278833627700806
#     y: 0.7626132369041443
#   }
#   relative_keypoints {
#     x: 0.7902508974075317
#     y: 0.8564777970314026
#   }
#   relative_keypoints {
#     x: 0.5388020277023315
#     y: 0.6324591040611267
#   }
#   relative_keypoints {
#     x: 0.8329383730888367
#     y: 0.6873344779014587
#   }
# }
#
# FPS:  69.65546790666778
# 0 label_id: 0
# score: 0.9171873927116394
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5190706849098206
#     ymin: 0.4930031895637512
#     width: 0.3662266731262207
#     height: 0.48822855949401855
#   }
#   relative_keypoints {
#     x: 0.7203754186630249
#     y: 0.624723494052887
#   }
#   relative_keypoints {
#     x: 0.8497781157493591
#     y: 0.6544696688652039
#   }
#   relative_keypoints {
#     x: 0.8325114846229553
#     y: 0.7591492533683777
#   }
#   relative_keypoints {
#     x: 0.7937914133071899
#     y: 0.8547602295875549
#   }
#   relative_keypoints {
#     x: 0.5379810929298401
#     y: 0.6357517242431641
#   }
#   relative_keypoints {
#     x: 0.8281764984130859
#     y: 0.689136803150177
#   }
# }
#
# FPS:  129.56980012974577
# 0 label_id: 0
# score: 0.911261260509491
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5158728361129761
#     ymin: 0.48073476552963257
#     width: 0.37467771768569946
#     height: 0.49949395656585693
#   }
#   relative_keypoints {
#     x: 0.7142106890678406
#     y: 0.6154511570930481
#   }
#   relative_keypoints {
#     x: 0.8498990535736084
#     y: 0.6407375335693359
#   }
#   relative_keypoints {
#     x: 0.8286877274513245
#     y: 0.7501790523529053
#   }
#   relative_keypoints {
#     x: 0.7931747436523438
#     y: 0.8484254479408264
#   }
#   relative_keypoints {
#     x: 0.5359352827072144
#     y: 0.6340668797492981
#   }
#   relative_keypoints {
#     x: 0.8360232710838318
#     y: 0.6778149604797363
#   }
# }
#
# FPS:  168.20950471225186
# 0 label_id: 0
# score: 0.8988271355628967
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5307062864303589
#     ymin: 0.4830129146575928
#     width: 0.3621823787689209
#     height: 0.48283201456069946
#   }
#   relative_keypoints {
#     x: 0.719109058380127
#     y: 0.6164531707763672
#   }
#   relative_keypoints {
#     x: 0.8515260219573975
#     y: 0.6398182511329651
#   }
#   relative_keypoints {
#     x: 0.8284572958946228
#     y: 0.7487432956695557
#   }
#   relative_keypoints {
#     x: 0.7942934036254883
#     y: 0.8413873314857483
#   }
#   relative_keypoints {
#     x: 0.547676682472229
#     y: 0.6277235150337219
#   }
#   relative_keypoints {
#     x: 0.8418669700622559
#     y: 0.6705665588378906
#   }
# }
#
# FPS:  121.96644275785862
# 0 label_id: 0
# score: 0.8998931050300598
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.522398054599762
#     ymin: 0.48066264390945435
#     width: 0.3659963607788086
#     height: 0.48792171478271484
#   }
#   relative_keypoints {
#     x: 0.7182377576828003
#     y: 0.6151869297027588
#   }
#   relative_keypoints {
#     x: 0.8542407751083374
#     y: 0.6377692222595215
#   }
#   relative_keypoints {
#     x: 0.8347131013870239
#     y: 0.7477607727050781
#   }
#   relative_keypoints {
#     x: 0.7977617383003235
#     y: 0.8424424529075623
#   }
#   relative_keypoints {
#     x: 0.5356298089027405
#     y: 0.6301555633544922
#   }
#   relative_keypoints {
#     x: 0.8375476002693176
#     y: 0.6717497706413269
#   }
# }
#
# FPS:  88.14155423864162
# 0 label_id: 0
# score: 0.9018101096153259
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5079905390739441
#     ymin: 0.46858125925064087
#     width: 0.382110595703125
#     height: 0.5094047784805298
#   }
#   relative_keypoints {
#     x: 0.7083936929702759
#     y: 0.6086719632148743
#   }
#   relative_keypoints {
#     x: 0.8470760583877563
#     y: 0.6311370730400085
#   }
#   relative_keypoints {
#     x: 0.8243080973625183
#     y: 0.7476651072502136
#   }
#   relative_keypoints {
#     x: 0.7891861200332642
#     y: 0.8458375334739685
#   }
#   relative_keypoints {
#     x: 0.5300337672233582
#     y: 0.6272446513175964
#   }
#   relative_keypoints {
#     x: 0.8361521363258362
#     y: 0.6679438948631287
#   }
# }
#
# FPS:  88.44264507422402
# 0 label_id: 0
# score: 0.8700342178344727
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5094567537307739
#     ymin: 0.4698578715324402
#     width: 0.37434959411621094
#     height: 0.4990558624267578
#   }
#   relative_keypoints {
#     x: 0.6994858980178833
#     y: 0.6109021306037903
#   }
#   relative_keypoints {
#     x: 0.8418174386024475
#     y: 0.6268542408943176
#   }
#   relative_keypoints {
#     x: 0.8165838718414307
#     y: 0.7469202876091003
#   }
#   relative_keypoints {
#     x: 0.7833576798439026
#     y: 0.8423628211021423
#   }
#   relative_keypoints {
#     x: 0.523015022277832
#     y: 0.6265307068824768
#   }
#   relative_keypoints {
#     x: 0.8364158868789673
#     y: 0.6578212380409241
#   }
# }
#
# FPS:  76.5607476635514
# 0 label_id: 0
# score: 0.8882974982261658
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5154383778572083
#     ymin: 0.4802510142326355
#     width: 0.370288610458374
#     height: 0.4936389923095703
#   }
#   relative_keypoints {
#     x: 0.6987558603286743
#     y: 0.6095256209373474
#   }
#   relative_keypoints {
#     x: 0.8418688774108887
#     y: 0.6291393637657166
#   }
#   relative_keypoints {
#     x: 0.8130373954772949
#     y: 0.7395207285881042
#   }
#   relative_keypoints {
#     x: 0.7815404534339905
#     y: 0.8407561182975769
#   }
#   relative_keypoints {
#     x: 0.5283567309379578
#     y: 0.6350942254066467
#   }
#   relative_keypoints {
#     x: 0.8412690162658691
#     y: 0.6697942614555359
#   }
# }
#
# FPS:  101.72695302078533
# 0 label_id: 0
# score: 0.9057591557502747
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5059545636177063
#     ymin: 0.46550220251083374
#     width: 0.3822612166404724
#     height: 0.5096042156219482
#   }
#   relative_keypoints {
#     x: 0.6955556273460388
#     y: 0.608961820602417
#   }
#   relative_keypoints {
#     x: 0.84023118019104
#     y: 0.6323392987251282
#   }
#   relative_keypoints {
#     x: 0.8073508143424988
#     y: 0.7524647116661072
#   }
#   relative_keypoints {
#     x: 0.7749422788619995
#     y: 0.8466687798500061
#   }
#   relative_keypoints {
#     x: 0.5248622298240662
#     y: 0.6205448508262634
#   }
#   relative_keypoints {
#     x: 0.8411518335342407
#     y: 0.664426326751709
#   }
# }
#
# FPS:  96.58286319570774
# 0 label_id: 0
# score: 0.9172232151031494
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5123671293258667
#     ymin: 0.47452181577682495
#     width: 0.37126094102859497
#     height: 0.4949609041213989
#   }
#   relative_keypoints {
#     x: 0.6995684504508972
#     y: 0.6116114258766174
#   }
#   relative_keypoints {
#     x: 0.8394308686256409
#     y: 0.6381233334541321
#   }
#   relative_keypoints {
#     x: 0.8081898093223572
#     y: 0.7514933943748474
#   }
#   relative_keypoints {
#     x: 0.7738764882087708
#     y: 0.8445983529090881
#   }
#   relative_keypoints {
#     x: 0.5256805419921875
#     y: 0.619202196598053
#   }
#   relative_keypoints {
#     x: 0.8347546458244324
#     y: 0.6675927042961121
#   }
# }
#
# FPS:  106.97299089494759
# 0 label_id: 0
# score: 0.9136689305305481
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5127612352371216
#     ymin: 0.47798866033554077
#     width: 0.3768083453178406
#     height: 0.502334713935852
#   }
#   relative_keypoints {
#     x: 0.697510838508606
#     y: 0.61464923620224
#   }
#   relative_keypoints {
#     x: 0.8438952565193176
#     y: 0.6380942463874817
#   }
#   relative_keypoints {
#     x: 0.8103309273719788
#     y: 0.7519181370735168
#   }
#   relative_keypoints {
#     x: 0.7789350748062134
#     y: 0.8482974171638489
#   }
#   relative_keypoints {
#     x: 0.5272938013076782
#     y: 0.6346502304077148
#   }
#   relative_keypoints {
#     x: 0.8464596271514893
#     y: 0.676052987575531
#   }
# }
#
# FPS:  108.20659408699241
# 0 label_id: 0
# score: 0.8524872064590454
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5410938858985901
#     ymin: 0.47725605964660645
#     width: 0.3825647830963135
#     height: 0.5099919438362122
#   }
#   relative_keypoints {
#     x: 0.7064388990402222
#     y: 0.61252361536026
#   }
#   relative_keypoints {
#     x: 0.864842414855957
#     y: 0.6307836174964905
#   }
#   relative_keypoints {
#     x: 0.8167992234230042
#     y: 0.7426347136497498
#   }
#   relative_keypoints {
#     x: 0.7903286814689636
#     y: 0.8490995764732361
#   }
#   relative_keypoints {
#     x: 0.5489584803581238
#     y: 0.6419212818145752
#   }
#   relative_keypoints {
#     x: 0.8857893347740173
#     y: 0.6772010922431946
#   }
# }
#
# FPS:  122.20453353534177
# 0 label_id: 0
# score: 0.7982997298240662
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5791738629341125
#     ymin: 0.4934304356575012
#     width: 0.3735426664352417
#     height: 0.497963547706604
#   }
#   relative_keypoints {
#     x: 0.7550074458122253
#     y: 0.6062109470367432
#   }
#   relative_keypoints {
#     x: 0.9091320633888245
#     y: 0.6315377354621887
#   }
#   relative_keypoints {
#     x: 0.8762649893760681
#     y: 0.7151246070861816
#   }
#   relative_keypoints {
#     x: 0.8440015912055969
#     y: 0.8346282839775085
#   }
#   relative_keypoints {
#     x: 0.5771257281303406
#     y: 0.6581568717956543
#   }
#   relative_keypoints {
#     x: 0.9106166958808899
#     y: 0.6966095566749573
#   }
# }
#
# FPS:  87.01514459980913
# 0 label_id: 0
# score: 0.8443892598152161
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6036126017570496
#     ymin: 0.5054617524147034
#     width: 0.3538706302642822
#     height: 0.47177863121032715
#   }
#   relative_keypoints {
#     x: 0.7983307242393494
#     y: 0.6229767203330994
#   }
#   relative_keypoints {
#     x: 0.9207372069358826
#     y: 0.6474602818489075
#   }
#   relative_keypoints {
#     x: 0.9068506956100464
#     y: 0.7459487915039062
#   }
#   relative_keypoints {
#     x: 0.8655361533164978
#     y: 0.848134458065033
#   }
#   relative_keypoints {
#     x: 0.6129404306411743
#     y: 0.6368456482887268
#   }
#   relative_keypoints {
#     x: 0.8914861679077148
#     y: 0.6853316426277161
#   }
# }
#
# FPS:  108.4892786011743
# 0 label_id: 0
# score: 0.861270546913147
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6164752244949341
#     ymin: 0.5003495812416077
#     width: 0.3551338315010071
#     height: 0.4734766483306885
#   }
#   relative_keypoints {
#     x: 0.8109419345855713
#     y: 0.6229320168495178
#   }
#   relative_keypoints {
#     x: 0.9319137930870056
#     y: 0.6487451195716858
#   }
#   relative_keypoints {
#     x: 0.9152118563652039
#     y: 0.7502758502960205
#   }
#   relative_keypoints {
#     x: 0.8740358948707581
#     y: 0.8497913479804993
#   }
#   relative_keypoints {
#     x: 0.6271589994430542
#     y: 0.632967472076416
#   }
#   relative_keypoints {
#     x: 0.9022322297096252
#     y: 0.6830387115478516
#   }
# }
#
# FPS:  93.83650275180098
# 0 label_id: 0
# score: 0.8976550698280334
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6207079887390137
#     ymin: 0.514568030834198
#     width: 0.3528923988342285
#     height: 0.4704943895339966
#   }
#   relative_keypoints {
#     x: 0.8283220529556274
#     y: 0.6416282057762146
#   }
#   relative_keypoints {
#     x: 0.9368612766265869
#     y: 0.6783564686775208
#   }
#   relative_keypoints {
#     x: 0.919174075126648
#     y: 0.7843284010887146
#   }
#   relative_keypoints {
#     x: 0.867390513420105
#     y: 0.8727479577064514
#   }
#   relative_keypoints {
#     x: 0.63762366771698
#     y: 0.6157172322273254
#   }
#   relative_keypoints {
#     x: 0.8923028707504272
#     y: 0.6975993514060974
#   }
# }
#
# FPS:  89.56064229586607
# 0 label_id: 0
# score: 0.8881988525390625
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6022865772247314
#     ymin: 0.5007774233818054
#     width: 0.3619551658630371
#     height: 0.48256468772888184
#   }
#   relative_keypoints {
#     x: 0.7863916158676147
#     y: 0.6144700050354004
#   }
#   relative_keypoints {
#     x: 0.9243131279945374
#     y: 0.6539711952209473
#   }
#   relative_keypoints {
#     x: 0.8891884088516235
#     y: 0.7490325570106506
#   }
#   relative_keypoints {
#     x: 0.8490168452262878
#     y: 0.8515800833702087
#   }
#   relative_keypoints {
#     x: 0.6093732118606567
#     y: 0.626369059085846
#   }
#   relative_keypoints {
#     x: 0.9160133004188538
#     y: 0.7018189430236816
#   }
# }
#
# FPS:  97.15559055847676
# 0 label_id: 0
# score: 0.8626243472099304
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5821514129638672
#     ymin: 0.4918327331542969
#     width: 0.3845406770706177
#     height: 0.5126429796218872
#   }
#   relative_keypoints {
#     x: 0.7456082105636597
#     y: 0.6098371148109436
#   }
#   relative_keypoints {
#     x: 0.9070770740509033
#     y: 0.6419048309326172
#   }
#   relative_keypoints {
#     x: 0.849519670009613
#     y: 0.7408513426780701
#   }
#   relative_keypoints {
#     x: 0.8196290135383606
#     y: 0.8553336262702942
#   }
#   relative_keypoints {
#     x: 0.591103732585907
#     y: 0.6417145133018494
#   }
#   relative_keypoints {
#     x: 0.9327083230018616
#     y: 0.7038924694061279
#   }
# }
#
# FPS:  141.1320703926781
# 0 label_id: 0
# score: 0.8484764099121094
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5568113923072815
#     ymin: 0.4854736924171448
#     width: 0.39378881454467773
#     height: 0.5249698758125305
#   }
#   relative_keypoints {
#     x: 0.6985476016998291
#     y: 0.6177999377250671
#   }
#   relative_keypoints {
#     x: 0.8732459545135498
#     y: 0.639870822429657
#   }
#   relative_keypoints {
#     x: 0.7998629808425903
#     y: 0.7480242252349854
#   }
#   relative_keypoints {
#     x: 0.779192328453064
#     y: 0.8614299893379211
#   }
#   relative_keypoints {
#     x: 0.5623328685760498
#     y: 0.6517460942268372
#   }
#   relative_keypoints {
#     x: 0.9266126155853271
#     y: 0.6971287131309509
#   }
# }
#
# FPS:  84.21958957471587
# 0 label_id: 0
# score: 0.8967648148536682
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5293465256690979
#     ymin: 0.5148711204528809
#     width: 0.357171893119812
#     height: 0.47618240118026733
#   }
#   relative_keypoints {
#     x: 0.6541126370429993
#     y: 0.6282008290290833
#   }
#   relative_keypoints {
#     x: 0.8156342506408691
#     y: 0.6444792151451111
#   }
#   relative_keypoints {
#     x: 0.7489715218544006
#     y: 0.7410587668418884
#   }
#   relative_keypoints {
#     x: 0.7351294755935669
#     y: 0.850328266620636
#   }
#   relative_keypoints {
#     x: 0.5335122346878052
#     y: 0.6716623902320862
#   }
#   relative_keypoints {
#     x: 0.8704743385314941
#     y: 0.6994428038597107
#   }
# }
#
# FPS:  108.74524241638579
# 0 label_id: 0
# score: 0.9047261476516724
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4752790033817291
#     ymin: 0.5061063170433044
#     width: 0.3840009272098541
#     height: 0.5119231343269348
#   }
#   relative_keypoints {
#     x: 0.5902690291404724
#     y: 0.6463114619255066
#   }
#   relative_keypoints {
#     x: 0.7653582692146301
#     y: 0.6330689787864685
#   }
#   relative_keypoints {
#     x: 0.695285975933075
#     y: 0.7601122260093689
#   }
#   relative_keypoints {
#     x: 0.6931849122047424
#     y: 0.8718370795249939
#   }
#   relative_keypoints {
#     x: 0.4803502559661865
#     y: 0.6984147429466248
#   }
#   relative_keypoints {
#     x: 0.8428577184677124
#     y: 0.6719911694526672
#   }
# }
#
# FPS:  92.13997935019002
# 0 label_id: 0
# score: 0.8877624869346619
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4445819854736328
#     ymin: 0.496795117855072
#     width: 0.37722522020339966
#     height: 0.5029181241989136
#   }
#   relative_keypoints {
#     x: 0.5686869025230408
#     y: 0.6429902911186218
#   }
#   relative_keypoints {
#     x: 0.7339087128639221
#     y: 0.637323796749115
#   }
#   relative_keypoints {
#     x: 0.6701575517654419
#     y: 0.7667140364646912
#   }
#   relative_keypoints {
#     x: 0.6646029949188232
#     y: 0.8660454154014587
#   }
#   relative_keypoints {
#     x: 0.45458388328552246
#     y: 0.6763951182365417
#   }
#   relative_keypoints {
#     x: 0.7995912432670593
#     y: 0.663367748260498
#   }
# }
#
# FPS:  129.8666749233675
# 0 label_id: 0
# score: 0.9109126329421997
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4273180067539215
#     ymin: 0.4821109175682068
#     width: 0.3871378004550934
#     height: 0.5161319971084595
#   }
#   relative_keypoints {
#     x: 0.5461065769195557
#     y: 0.6436359286308289
#   }
#   relative_keypoints {
#     x: 0.7154894471168518
#     y: 0.6280239224433899
#   }
#   relative_keypoints {
#     x: 0.6491299271583557
#     y: 0.77054762840271
#   }
#   relative_keypoints {
#     x: 0.6501027941703796
#     y: 0.8672868609428406
#   }
#   relative_keypoints {
#     x: 0.4404272735118866
#     y: 0.6796948909759521
#   }
#   relative_keypoints {
#     x: 0.7916234731674194
#     y: 0.6453595161437988
#   }
# }
#
# FPS:  101.09679907443116
# 0 label_id: 0
# score: 0.9231894612312317
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41237279772758484
#     ymin: 0.4729699492454529
#     width: 0.401180237531662
#     height: 0.5348216891288757
#   }
#   relative_keypoints {
#     x: 0.5361135005950928
#     y: 0.6514599323272705
#   }
#   relative_keypoints {
#     x: 0.7096226811408997
#     y: 0.6309497356414795
#   }
#   relative_keypoints {
#     x: 0.642470121383667
#     y: 0.7869706153869629
#   }
#   relative_keypoints {
#     x: 0.6435701847076416
#     y: 0.8784063458442688
#   }
#   relative_keypoints {
#     x: 0.42674678564071655
#     y: 0.6781191229820251
#   }
#   relative_keypoints {
#     x: 0.7876212000846863
#     y: 0.6373193860054016
#   }
# }
#
# FPS:  126.7161329305136
# 0 label_id: 0
# score: 0.9256515502929688
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41152411699295044
#     ymin: 0.4724085330963135
#     width: 0.4002390503883362
#     height: 0.5335668325424194
#   }
#   relative_keypoints {
#     x: 0.5369990468025208
#     y: 0.6454594135284424
#   }
#   relative_keypoints {
#     x: 0.707653820514679
#     y: 0.6310130953788757
#   }
#   relative_keypoints {
#     x: 0.6391541957855225
#     y: 0.7830622792243958
#   }
#   relative_keypoints {
#     x: 0.6382911205291748
#     y: 0.8758912682533264
#   }
#   relative_keypoints {
#     x: 0.4287339746952057
#     y: 0.6725054383277893
#   }
#   relative_keypoints {
#     x: 0.7840602397918701
#     y: 0.6430737376213074
#   }
# }
#
# FPS:  104.24775065864692
# 0 label_id: 0
# score: 0.9184921383857727
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.41645511984825134
#     ymin: 0.4784840941429138
#     width: 0.3961199223995209
#     height: 0.5280750393867493
#   }
#   relative_keypoints {
#     x: 0.5395659804344177
#     y: 0.6496091485023499
#   }
#   relative_keypoints {
#     x: 0.7098451256752014
#     y: 0.6318051218986511
#   }
#   relative_keypoints {
#     x: 0.64360111951828
#     y: 0.7822458744049072
#   }
#   relative_keypoints {
#     x: 0.6437382102012634
#     y: 0.8759276270866394
#   }
#   relative_keypoints {
#     x: 0.4314238429069519
#     y: 0.6797229647636414
#   }
#   relative_keypoints {
#     x: 0.7855005860328674
#     y: 0.6434540748596191
#   }
# }
#
# FPS:  127.9258242596151
# 0 label_id: 0
# score: 0.9142290949821472
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42386090755462646
#     ymin: 0.48713332414627075
#     width: 0.39579445123672485
#     height: 0.527640163898468
#   }
#   relative_keypoints {
#     x: 0.5513643622398376
#     y: 0.6502456068992615
#   }
#   relative_keypoints {
#     x: 0.716658890247345
#     y: 0.6330781579017639
#   }
#   relative_keypoints {
#     x: 0.6545110940933228
#     y: 0.7776947617530823
#   }
#   relative_keypoints {
#     x: 0.6539343595504761
#     y: 0.8775604367256165
#   }
#   relative_keypoints {
#     x: 0.4429447650909424
#     y: 0.6906206607818604
#   }
#   relative_keypoints {
#     x: 0.7881805896759033
#     y: 0.6547772288322449
#   }
# }
#
# FPS:  95.71010656504575
# 0 label_id: 0
# score: 0.9122079014778137
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42636072635650635
#     ymin: 0.4806285500526428
#     width: 0.3956703543663025
#     height: 0.5274732708930969
#   }
#   relative_keypoints {
#     x: 0.5529851317405701
#     y: 0.6466389298439026
#   }
#   relative_keypoints {
#     x: 0.7175448536872864
#     y: 0.6280816197395325
#   }
#   relative_keypoints {
#     x: 0.6552451252937317
#     y: 0.7754330635070801
#   }
#   relative_keypoints {
#     x: 0.6555181741714478
#     y: 0.872499406337738
#   }
#   relative_keypoints {
#     x: 0.4461183249950409
#     y: 0.6839628219604492
#   }
#   relative_keypoints {
#     x: 0.7904995083808899
#     y: 0.6459321975708008
#   }
# }
#
# FPS:  97.06565457869524
# 0 label_id: 0
# score: 0.8967025876045227
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4303275942802429
#     ymin: 0.48111265897750854
#     width: 0.39366257190704346
#     height: 0.5247990489006042
#   }
#   relative_keypoints {
#     x: 0.5612434148788452
#     y: 0.648686408996582
#   }
#   relative_keypoints {
#     x: 0.7274003028869629
#     y: 0.6265530586242676
#   }
#   relative_keypoints {
#     x: 0.670871376991272
#     y: 0.7746670246124268
#   }
#   relative_keypoints {
#     x: 0.6696892976760864
#     y: 0.8720342516899109
#   }
#   relative_keypoints {
#     x: 0.445374071598053
#     y: 0.6862893104553223
#   }
#   relative_keypoints {
#     x: 0.792883574962616
#     y: 0.6416595578193665
#   }
# }
#
# FPS:  89.17031273252971
# 0 label_id: 0
# score: 0.91280198097229
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44133129715919495
#     ymin: 0.48243165016174316
#     width: 0.3872276842594147
#     height: 0.5162327885627747
#   }
#   relative_keypoints {
#     x: 0.5776095390319824
#     y: 0.6389485001564026
#   }
#   relative_keypoints {
#     x: 0.7406559586524963
#     y: 0.6267654895782471
#   }
#   relative_keypoints {
#     x: 0.6857648491859436
#     y: 0.7660152316093445
#   }
#   relative_keypoints {
#     x: 0.679726779460907
#     y: 0.86404949426651
#   }
#   relative_keypoints {
#     x: 0.45500707626342773
#     y: 0.6713387370109558
#   }
#   relative_keypoints {
#     x: 0.7979500889778137
#     y: 0.6459001898765564
#   }
# }
#
# FPS:  117.05469970975665
# 0 label_id: 0
# score: 0.9288716912269592
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.44496068358421326
#     ymin: 0.48508554697036743
#     width: 0.38530996441841125
#     height: 0.5136940479278564
#   }
#   relative_keypoints {
#     x: 0.5865436792373657
#     y: 0.6300156116485596
#   }
#   relative_keypoints {
#     x: 0.7493253946304321
#     y: 0.6348466277122498
#   }
#   relative_keypoints {
#     x: 0.6896511912345886
#     y: 0.7629266381263733
#   }
#   relative_keypoints {
#     x: 0.6771131753921509
#     y: 0.8625974059104919
#   }
#   relative_keypoints {
#     x: 0.4571726322174072
#     y: 0.6573736667633057
#   }
#   relative_keypoints {
#     x: 0.8003365397453308
#     y: 0.6658971905708313
#   }
# }
#
# FPS:  108.67480243554864
# 0 label_id: 0
# score: 0.9244112968444824
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4486728012561798
#     ymin: 0.4854860305786133
#     width: 0.38934412598609924
#     height: 0.5190403461456299
#   }
#   relative_keypoints {
#     x: 0.5888726115226746
#     y: 0.6394443511962891
#   }
#   relative_keypoints {
#     x: 0.7503640651702881
#     y: 0.6344950199127197
#   }
#   relative_keypoints {
#     x: 0.6931055188179016
#     y: 0.7712302803993225
#   }
#   relative_keypoints {
#     x: 0.6840177178382874
#     y: 0.8687136769294739
#   }
#   relative_keypoints {
#     x: 0.46360868215560913
#     y: 0.6680375933647156
#   }
#   relative_keypoints {
#     x: 0.8049362897872925
#     y: 0.6579930782318115
#   }
# }
#
# FPS:  111.50022596166627
# 0 label_id: 0
# score: 0.9279632568359375
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4547532796859741
#     ymin: 0.48802435398101807
#     width: 0.38395291566848755
#     height: 0.5118870139122009
#   }
#   relative_keypoints {
#     x: 0.594619870185852
#     y: 0.6344224810600281
#   }
#   relative_keypoints {
#     x: 0.7586075067520142
#     y: 0.636576235294342
#   }
#   relative_keypoints {
#     x: 0.699385404586792
#     y: 0.7656973004341125
#   }
#   relative_keypoints {
#     x: 0.6873974800109863
#     y: 0.8645947575569153
#   }
#   relative_keypoints {
#     x: 0.46475040912628174
#     y: 0.6592504978179932
#   }
#   relative_keypoints {
#     x: 0.8109738230705261
#     y: 0.663104236125946
#   }
# }
#
# FPS:  99.1186312505908
# 0 label_id: 0
# score: 0.9302796721458435
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4578951895236969
#     ymin: 0.48266446590423584
#     width: 0.3923182785511017
#     height: 0.5230045318603516
#   }
#   relative_keypoints {
#     x: 0.5926175713539124
#     y: 0.6402574181556702
#   }
#   relative_keypoints {
#     x: 0.7572456002235413
#     y: 0.6352286338806152
#   }
#   relative_keypoints {
#     x: 0.6948383450508118
#     y: 0.7763175368309021
#   }
#   relative_keypoints {
#     x: 0.6878872513771057
#     y: 0.8723672032356262
#   }
#   relative_keypoints {
#     x: 0.4716750979423523
#     y: 0.6637115478515625
#   }
#   relative_keypoints {
#     x: 0.8191145658493042
#     y: 0.6538715362548828
#   }
# }
#
# FPS:  128.2701000030582
# 0 label_id: 0
# score: 0.9288564920425415
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45893529057502747
#     ymin: 0.4916410446166992
#     width: 0.39134904742240906
#     height: 0.5217170715332031
#   }
#   relative_keypoints {
#     x: 0.5968107581138611
#     y: 0.6412815451622009
#   }
#   relative_keypoints {
#     x: 0.7604266405105591
#     y: 0.6415378451347351
#   }
#   relative_keypoints {
#     x: 0.6969928741455078
#     y: 0.7769271731376648
#   }
#   relative_keypoints {
#     x: 0.68695068359375
#     y: 0.8763229250907898
#   }
#   relative_keypoints {
#     x: 0.47435200214385986
#     y: 0.6656970381736755
#   }
#   relative_keypoints {
#     x: 0.8193264007568359
#     y: 0.6678063273429871
#   }
# }
#
# FPS:  98.06420238011737
# 0 label_id: 0
# score: 0.9215070605278015
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.45858052372932434
#     ymin: 0.4946082830429077
#     width: 0.3953770697116852
#     height: 0.5270851850509644
#   }
#   relative_keypoints {
#     x: 0.5936017036437988
#     y: 0.638566792011261
#   }
#   relative_keypoints {
#     x: 0.7618352770805359
#     y: 0.640310525894165
#   }
#   relative_keypoints {
#     x: 0.6935569643974304
#     y: 0.772209644317627
#   }
#   relative_keypoints {
#     x: 0.6843384504318237
#     y: 0.8784223198890686
#   }
#   relative_keypoints {
#     x: 0.47332102060317993
#     y: 0.6715586185455322
#   }
#   relative_keypoints {
#     x: 0.8255591988563538
#     y: 0.6760363578796387
#   }
# }
#
# FPS:  142.77995642701526
# 0 label_id: 0
# score: 0.9227951169013977
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4543023705482483
#     ymin: 0.47852182388305664
#     width: 0.3995131254196167
#     height: 0.5325957536697388
#   }
#   relative_keypoints {
#     x: 0.5951725244522095
#     y: 0.6394448280334473
#   }
#   relative_keypoints {
#     x: 0.7607693076133728
#     y: 0.6349032521247864
#   }
#   relative_keypoints {
#     x: 0.6995648145675659
#     y: 0.7798122763633728
#   }
#   relative_keypoints {
#     x: 0.6914894580841064
#     y: 0.8768830895423889
#   }
#   relative_keypoints {
#     x: 0.47045275568962097
#     y: 0.6613737940788269
#   }
#   relative_keypoints {
#     x: 0.8200667500495911
#     y: 0.6526069045066833
#   }
# }
#
# FPS:  81.66638758542807
# 0 label_id: 0
# score: 0.920136570930481
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.46191462874412537
#     ymin: 0.4954637289047241
#     width: 0.3889491856098175
#     height: 0.5185177326202393
#   }
#   relative_keypoints {
#     x: 0.6020194292068481
#     y: 0.6424064040184021
#   }
#   relative_keypoints {
#     x: 0.7670615315437317
#     y: 0.6412535309791565
#   }
#   relative_keypoints {
#     x: 0.707122802734375
#     y: 0.7744076251983643
#   }
#   relative_keypoints {
#     x: 0.6957409381866455
#     y: 0.8757291436195374
#   }
#   relative_keypoints {
#     x: 0.4725525975227356
#     y: 0.6693757176399231
#   }
#   relative_keypoints {
#     x: 0.8217319846153259
#     y: 0.6683803200721741
#   }
# }
#
# FPS:  97.0072854268335
# 0 label_id: 0
# score: 0.911101758480072
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4624575674533844
#     ymin: 0.49824488162994385
#     width: 0.38737258315086365
#     height: 0.516417384147644
#   }
#   relative_keypoints {
#     x: 0.6135348081588745
#     y: 0.6310693621635437
#   }
#   relative_keypoints {
#     x: 0.7722090482711792
#     y: 0.645820140838623
#   }
#   relative_keypoints {
#     x: 0.7129789590835571
#     y: 0.7662582397460938
#   }
#   relative_keypoints {
#     x: 0.6942259669303894
#     y: 0.8724148869514465
#   }
#   relative_keypoints {
#     x: 0.47834911942481995
#     y: 0.6588528752326965
#   }
#   relative_keypoints {
#     x: 0.8155629634857178
#     y: 0.6877976059913635
#   }
# }
#
# FPS:  75.65619870488284
# 0 label_id: 0
# score: 0.899573564529419
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.46807587146759033
#     ymin: 0.48461753129959106
#     width: 0.381730854511261
#     height: 0.5088980197906494
#   }
#   relative_keypoints {
#     x: 0.6303459405899048
#     y: 0.6274557709693909
#   }
#   relative_keypoints {
#     x: 0.7853735685348511
#     y: 0.6320850253105164
#   }
#   relative_keypoints {
#     x: 0.742107093334198
#     y: 0.7583687901496887
#   }
#   relative_keypoints {
#     x: 0.7212504148483276
#     y: 0.8584707379341125
#   }
#   relative_keypoints {
#     x: 0.47880032658576965
#     y: 0.6521062254905701
#   }
#   relative_keypoints {
#     x: 0.8117128014564514
#     y: 0.661694347858429
#   }
# }
#
# FPS:  114.46399039379963
# 0 label_id: 0
# score: 0.9278307557106018
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.46940523386001587
#     ymin: 0.4875233769416809
#     width: 0.3935309052467346
#     height: 0.5246279835700989
#   }
#   relative_keypoints {
#     x: 0.6372604966163635
#     y: 0.6181572079658508
#   }
#   relative_keypoints {
#     x: 0.7968538403511047
#     y: 0.6349446177482605
#   }
#   relative_keypoints {
#     x: 0.7468414306640625
#     y: 0.753166139125824
#   }
#   relative_keypoints {
#     x: 0.7224566340446472
#     y: 0.8628188967704773
#   }
#   relative_keypoints {
#     x: 0.4841429591178894
#     y: 0.6483332514762878
#   }
#   relative_keypoints {
#     x: 0.8259771466255188
#     y: 0.6822025775909424
#   }
# }
#
# FPS:  94.3218494198075
# 0 label_id: 0
# score: 0.9302939176559448
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.47169816493988037
#     ymin: 0.4762648940086365
#     width: 0.38323551416397095
#     height: 0.5109250545501709
#   }
#   relative_keypoints {
#     x: 0.6416860818862915
#     y: 0.6122068762779236
#   }
#   relative_keypoints {
#     x: 0.795464038848877
#     y: 0.6303169131278992
#   }
#   relative_keypoints {
#     x: 0.7488104701042175
#     y: 0.749045193195343
#   }
#   relative_keypoints {
#     x: 0.7209838032722473
#     y: 0.8496833443641663
#   }
#   relative_keypoints {
#     x: 0.4830857217311859
#     y: 0.6295823454856873
#   }
#   relative_keypoints {
#     x: 0.8149818778038025
#     y: 0.6693627834320068
#   }
# }
#
# FPS:  112.16216071667336
# 0 label_id: 0
# score: 0.9187347888946533
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4742756485939026
#     ymin: 0.48064249753952026
#     width: 0.3841806650161743
#     height: 0.5121656656265259
#   }
#   relative_keypoints {
#     x: 0.6490979790687561
#     y: 0.6141386032104492
#   }
#   relative_keypoints {
#     x: 0.8016692996025085
#     y: 0.6377986073493958
#   }
#   relative_keypoints {
#     x: 0.757582426071167
#     y: 0.7548168301582336
#   }
#   relative_keypoints {
#     x: 0.7284541726112366
#     y: 0.85476154088974
#   }
#   relative_keypoints {
#     x: 0.48887568712234497
#     y: 0.6307992935180664
#   }
#   relative_keypoints {
#     x: 0.8176209926605225
#     y: 0.6775763630867004
#   }
# }
#
# FPS:  95.14561168704489
# 0 label_id: 0
# score: 0.9248644113540649
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4798888564109802
#     ymin: 0.48080921173095703
#     width: 0.382999062538147
#     height: 0.5105895400047302
#   }
#   relative_keypoints {
#     x: 0.6532350778579712
#     y: 0.6150446534156799
#   }
#   relative_keypoints {
#     x: 0.8076021671295166
#     y: 0.6382022500038147
#   }
#   relative_keypoints {
#     x: 0.7624732255935669
#     y: 0.7555832266807556
#   }
#   relative_keypoints {
#     x: 0.7335833311080933
#     y: 0.8542584776878357
#   }
#   relative_keypoints {
#     x: 0.49166339635849
#     y: 0.6315428614616394
#   }
#   relative_keypoints {
#     x: 0.8247151970863342
#     y: 0.6779246926307678
#   }
# }
#
# FPS:  115.04481869548522
# 0 label_id: 0
# score: 0.9374001026153564
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4766232371330261
#     ymin: 0.4825631380081177
#     width: 0.38507843017578125
#     height: 0.5133594870567322
#   }
#   relative_keypoints {
#     x: 0.6509948372840881
#     y: 0.612393856048584
#   }
#   relative_keypoints {
#     x: 0.8058428168296814
#     y: 0.6301494240760803
#   }
#   relative_keypoints {
#     x: 0.7636575102806091
#     y: 0.7449918389320374
#   }
#   relative_keypoints {
#     x: 0.7368116974830627
#     y: 0.8502944111824036
#   }
#   relative_keypoints {
#     x: 0.4897143542766571
#     y: 0.6435404419898987
#   }
#   relative_keypoints {
#     x: 0.8236450552940369
#     y: 0.6769487261772156
#   }
# }
#
# FPS:  152.8926475412824
# 0 label_id: 0
# score: 0.9264252185821533
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.47081586718559265
#     ymin: 0.4780650734901428
#     width: 0.38929733633995056
#     height: 0.5189859867095947
#   }
#   relative_keypoints {
#     x: 0.6477682590484619
#     y: 0.6143531203269958
#   }
#   relative_keypoints {
#     x: 0.8035591244697571
#     y: 0.6294938921928406
#   }
#   relative_keypoints {
#     x: 0.7630195617675781
#     y: 0.7493996024131775
#   }
#   relative_keypoints {
#     x: 0.7362703084945679
#     y: 0.8531791567802429
#   }
#   relative_keypoints {
#     x: 0.484212189912796
#     y: 0.6419522166252136
#   }
#   relative_keypoints {
#     x: 0.8195816874504089
#     y: 0.6714711785316467
#   }
# }
#
# FPS:  117.99319211185191
# 0 label_id: 0
# score: 0.9290956854820251
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4801255464553833
#     ymin: 0.47825878858566284
#     width: 0.3806431293487549
#     height: 0.5074704885482788
#   }
#   relative_keypoints {
#     x: 0.6549721360206604
#     y: 0.6145692467689514
#   }
#   relative_keypoints {
#     x: 0.8098542094230652
#     y: 0.6358089447021484
#   }
#   relative_keypoints {
#     x: 0.7658591866493225
#     y: 0.7516674995422363
#   }
#   relative_keypoints {
#     x: 0.7353315353393555
#     y: 0.8502827286720276
#   }
#   relative_keypoints {
#     x: 0.48599720001220703
#     y: 0.6274461150169373
#   }
#   relative_keypoints {
#     x: 0.8225903511047363
#     y: 0.6717789769172668
#   }
# }
#
# FPS:  89.34316022664338
# 0 label_id: 0
# score: 0.9180481433868408
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4797118306159973
#     ymin: 0.4843263626098633
#     width: 0.3813987970352173
#     height: 0.5084561705589294
#   }
#   relative_keypoints {
#     x: 0.6578384637832642
#     y: 0.6207899451255798
#   }
#   relative_keypoints {
#     x: 0.8091296553611755
#     y: 0.6420919299125671
#   }
#   relative_keypoints {
#     x: 0.7689263820648193
#     y: 0.7616605162620544
#   }
#   relative_keypoints {
#     x: 0.7390981316566467
#     y: 0.8584911227226257
#   }
#   relative_keypoints {
#     x: 0.49296197295188904
#     y: 0.6353407502174377
#   }
#   relative_keypoints {
#     x: 0.820575475692749
#     y: 0.6779623627662659
#   }
# }
#
# FPS:  107.75624293495017
# 0 label_id: 0
# score: 0.9383146166801453
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48803865909576416
#     ymin: 0.4871184825897217
#     width: 0.37910014390945435
#     height: 0.5054137110710144
#   }
#   relative_keypoints {
#     x: 0.6625874042510986
#     y: 0.6170507073402405
#   }
#   relative_keypoints {
#     x: 0.8142529129981995
#     y: 0.6406264901161194
#   }
#   relative_keypoints {
#     x: 0.7713214159011841
#     y: 0.7528347373008728
#   }
#   relative_keypoints {
#     x: 0.7421977519989014
#     y: 0.8546295762062073
#   }
#   relative_keypoints {
#     x: 0.49810534715652466
#     y: 0.6372973322868347
#   }
#   relative_keypoints {
#     x: 0.8279903531074524
#     y: 0.6821592450141907
#   }
# }
#
# FPS:  90.8940080182035
# 0 label_id: 0
# score: 0.9126231074333191
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.48375558853149414
#     ymin: 0.4905669689178467
#     width: 0.37972593307495117
#     height: 0.5062258839607239
#   }
#   relative_keypoints {
#     x: 0.6596313118934631
#     y: 0.6214713454246521
#   }
#   relative_keypoints {
#     x: 0.8112888932228088
#     y: 0.6456807255744934
#   }
#   relative_keypoints {
#     x: 0.7689588069915771
#     y: 0.7606146931648254
#   }
#   relative_keypoints {
#     x: 0.7392065525054932
#     y: 0.8603643774986267
#   }
#   relative_keypoints {
#     x: 0.49625152349472046
#     y: 0.6389004588127136
#   }
#   relative_keypoints {
#     x: 0.8239760994911194
#     y: 0.6859055161476135
#   }
# }
#
# FPS:  93.86590278399427
# 0 label_id: 0
# score: 0.9197842478752136
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4839523732662201
#     ymin: 0.4847370386123657
#     width: 0.38075390458106995
#     height: 0.5075952410697937
#   }
#   relative_keypoints {
#     x: 0.6588386297225952
#     y: 0.6242995262145996
#   }
#   relative_keypoints {
#     x: 0.809301495552063
#     y: 0.640601634979248
#   }
#   relative_keypoints {
#     x: 0.7699458599090576
#     y: 0.7627582550048828
#   }
#   relative_keypoints {
#     x: 0.7434110045433044
#     y: 0.8594638705253601
#   }
#   relative_keypoints {
#     x: 0.4985992908477783
#     y: 0.6412544250488281
#   }
#   relative_keypoints {
#     x: 0.823651909828186
#     y: 0.6729891300201416
#   }
# }
#
# FPS:  98.88494907582044
# 0 label_id: 0
# score: 0.9382795095443726
# ...
#   }
#   relative_keypoints {
#     x: 0.45718902349472046
#     y: 0.5830481052398682
#   }
#   relative_keypoints {
#     x: 0.41093558073043823
#     y: 0.7063076496124268
#   }
#   relative_keypoints {
#     x: 0.3817864954471588
#     y: 0.8439670205116272
#   }
#   relative_keypoints {
#     x: 0.08312766999006271
#     y: 0.6314178109169006
#   }
#   relative_keypoints {
#     x: 0.4751735329627991
#     y: 0.6517758965492249
#   }
# }
#
# FPS:  82.26706417699671
# 0 label_id: 0
# score: 0.8258439898490906
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.0944267213344574
#     ymin: 0.4387853741645813
#     width: 0.4238460958003998
#     height: 0.5650443434715271
#   }
#   relative_keypoints {
#     x: 0.2755407392978668
#     y: 0.5666680932044983
#   }
#   relative_keypoints {
#     x: 0.4578559398651123
#     y: 0.5756946206092834
#   }
#   relative_keypoints {
#     x: 0.4165584444999695
#     y: 0.6725938320159912
#   }
#   relative_keypoints {
#     x: 0.3917706310749054
#     y: 0.8150100708007812
#   }
#   relative_keypoints {
#     x: 0.09483584761619568
#     y: 0.6430996060371399
#   }
#   relative_keypoints {
#     x: 0.4750981330871582
#     y: 0.6509008407592773
#   }
# }
#
# FPS:  87.87011082479626
# 0 label_id: 0
# score: 0.7794734835624695
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.08926081657409668
#     ymin: 0.40247589349746704
#     width: 0.4544095993041992
#     height: 0.6058185696601868
#   }
#   relative_keypoints {
#     x: 0.27541446685791016
#     y: 0.5514969229698181
#   }
#   relative_keypoints {
#     x: 0.45997878909111023
#     y: 0.5666610598564148
#   }
#   relative_keypoints {
#     x: 0.3963490426540375
#     y: 0.6972888112068176
#   }
#   relative_keypoints {
#     x: 0.36965981125831604
#     y: 0.8353822827339172
#   }
#   relative_keypoints {
#     x: 0.11309780180454254
#     y: 0.603665292263031
#   }
#   relative_keypoints {
#     x: 0.49461618065834045
#     y: 0.64040607213974
#   }
# }
#
# FPS:  95.76911133436843
# 0 label_id: 0
# score: 0.7799353003501892
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.08930587768554688
#     ymin: 0.4127351641654968
#     width: 0.42698216438293457
#     height: 0.5692414045333862
#   }
#   relative_keypoints {
#     x: 0.2972789704799652
#     y: 0.552006721496582
#   }
#   relative_keypoints {
#     x: 0.46255728602409363
#     y: 0.5893333554267883
#   }
#   relative_keypoints {
#     x: 0.41689640283584595
#     y: 0.7071888446807861
#   }
#   relative_keypoints {
#     x: 0.3745926022529602
#     y: 0.8282166123390198
#   }
#   relative_keypoints {
#     x: 0.10935013741254807
#     y: 0.5714106559753418
#   }
#   relative_keypoints {
#     x: 0.4607565402984619
#     y: 0.6528315544128418
#   }
# }
#
# FPS:  92.65699074380896
# 0 label_id: 0
# score: 0.8044936656951904
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.07831194251775742
#     ymin: 0.4302883744239807
#     width: 0.42488589882850647
#     height: 0.5664335489273071
#   }
#   relative_keypoints {
#     x: 0.2858363389968872
#     y: 0.5652286410331726
#   }
#   relative_keypoints {
#     x: 0.45286819338798523
#     y: 0.5950462222099304
#   }
#   relative_keypoints {
#     x: 0.4146218001842499
#     y: 0.7120855450630188
#   }
#   relative_keypoints {
#     x: 0.3754727244377136
#     y: 0.8375599980354309
#   }
#   relative_keypoints {
#     x: 0.09230905026197433
#     y: 0.5939896702766418
#   }
#   relative_keypoints {
#     x: 0.44906145334243774
#     y: 0.6568183898925781
#   }
# }
#
# FPS:  103.21645831282606
# 0 label_id: 0
# score: 0.8036025166511536
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.08158071339130402
#     ymin: 0.4290183186531067
#     width: 0.4363778829574585
#     height: 0.581752359867096
#   }
#   relative_keypoints {
#     x: 0.27889519929885864
#     y: 0.5760319828987122
#   }
#   relative_keypoints {
#     x: 0.45405179262161255
#     y: 0.5975624918937683
#   }
#   relative_keypoints {
#     x: 0.4056394696235657
#     y: 0.7263712286949158
#   }
#   relative_keypoints {
#     x: 0.3724277913570404
#     y: 0.8517152667045593
#   }
#   relative_keypoints {
#     x: 0.09774596989154816
#     y: 0.6060207486152649
#   }
#   relative_keypoints {
#     x: 0.46626272797584534
#     y: 0.6556472182273865
#   }
# }
#
# FPS:  85.88901175410575
# 0 label_id: 0
# score: 0.7637773752212524
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.08162211626768112
#     ymin: 0.41686517000198364
#     width: 0.43602418899536133
#     height: 0.581283450126648
#   }
#   relative_keypoints {
#     x: 0.28297606110572815
#     y: 0.5734410881996155
#   }
#   relative_keypoints {
#     x: 0.45605286955833435
#     y: 0.5910298824310303
#   }
#   relative_keypoints {
#     x: 0.41487228870391846
#     y: 0.7265069484710693
#   }
#   relative_keypoints {
#     x: 0.38073357939720154
#     y: 0.8472588658332825
#   }
#   relative_keypoints {
#     x: 0.09561705589294434
#     y: 0.5988666415214539
#   }
#   relative_keypoints {
#     x: 0.46125921607017517
#     y: 0.6397247314453125
#   }
# }
#
# FPS:  90.82315237868387
# 0 label_id: 0
# score: 0.7622238397598267
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.07308448851108551
#     ymin: 0.40462642908096313
#     width: 0.44432520866394043
#     height: 0.5923681259155273
#   }
#   relative_keypoints {
#     x: 0.28299784660339355
#     y: 0.5668818950653076
#   }
#   relative_keypoints {
#     x: 0.45419129729270935
#     y: 0.5946462154388428
#   }
#   relative_keypoints {
#     x: 0.40830308198928833
#     y: 0.7358291745185852
#   }
#   relative_keypoints {
#     x: 0.36866265535354614
#     y: 0.852633535861969
#   }
#   relative_keypoints {
#     x: 0.09453395754098892
#     y: 0.5787093043327332
#   }
#   relative_keypoints {
#     x: 0.4576069414615631
#     y: 0.642345666885376
#   }
# }
#
# FPS:  99.47359184157476
# 0 label_id: 0
# score: 0.8567607402801514
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.09708105772733688
#     ymin: 0.4281236529350281
#     width: 0.40401631593704224
#     height: 0.5386067628860474
#   }
#   relative_keypoints {
#     x: 0.30194103717803955
#     y: 0.5522754192352295
#   }
#   relative_keypoints {
#     x: 0.4573877155780792
#     y: 0.5831711888313293
#   }
#   relative_keypoints {
#     x: 0.42775508761405945
#     y: 0.6805195808410645
#   }
#   relative_keypoints {
#     x: 0.38732418417930603
#     y: 0.8037320971488953
#   }
#   relative_keypoints {
#     x: 0.10814366489648819
#     y: 0.5931327939033508
#   }
#   relative_keypoints {
#     x: 0.4467897415161133
#     y: 0.6537184715270996
#   }
# }
#
# FPS:  86.64664201458467
# 0 label_id: 0
# score: 0.8518823385238647
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.11288288980722427
#     ymin: 0.41743195056915283
#     width: 0.411459356546402
#     height: 0.5485357642173767
#   }
#   relative_keypoints {
#     x: 0.3238717317581177
#     y: 0.5515757203102112
#   }
#   relative_keypoints {
#     x: 0.47584372758865356
#     y: 0.5874608159065247
#   }
#   relative_keypoints {
#     x: 0.4429130554199219
#     y: 0.6984458565711975
#   }
#   relative_keypoints {
#     x: 0.3985743522644043
#     y: 0.8152965903282166
#   }
#   relative_keypoints {
#     x: 0.13171575963497162
#     y: 0.5743327140808105
#   }
#   relative_keypoints {
#     x: 0.46354058384895325
#     y: 0.6511242389678955
#   }
# }
#
# FPS:  100.37581965251519
# 0 label_id: 0
# score: 0.8392115235328674
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.13118356466293335
#     ymin: 0.4420319199562073
#     width: 0.4033028483390808
#     height: 0.5376526117324829
#   }
#   relative_keypoints {
#     x: 0.32834920287132263
#     y: 0.5521249175071716
#   }
#   relative_keypoints {
#     x: 0.4962552487850189
#     y: 0.5921534895896912
#   }
#   relative_keypoints {
#     x: 0.4559940993785858
#     y: 0.6749191880226135
#   }
#   relative_keypoints {
#     x: 0.4121673107147217
#     y: 0.8068895936012268
#   }
#   relative_keypoints {
#     x: 0.13076482713222504
#     y: 0.5988574028015137
#   }
#   relative_keypoints {
#     x: 0.4932638108730316
#     y: 0.6737766861915588
#   }
# }
#
# FPS:  80.82133497764761
# 0 label_id: 0
# score: 0.8550513982772827
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.13600412011146545
#     ymin: 0.4415493607521057
#     width: 0.4068783223628998
#     height: 0.5424177646636963
#   }
#   relative_keypoints {
#     x: 0.348326712846756
#     y: 0.5552248954772949
#   }
#   relative_keypoints {
#     x: 0.5097461342811584
#     y: 0.592881441116333
#   }
#   relative_keypoints {
#     x: 0.4821108281612396
#     y: 0.6821725368499756
#   }
#   relative_keypoints {
#     x: 0.43520691990852356
#     y: 0.8141708970069885
#   }
#   relative_keypoints {
#     x: 0.14032545685768127
#     y: 0.5991020798683167
#   }
#   relative_keypoints {
#     x: 0.4930727481842041
#     y: 0.6696805357933044
#   }
# }
#
# FPS:  82.7050518594471
# 0 label_id: 0
# score: 0.8250475525856018
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.14373521506786346
#     ymin: 0.4449526071548462
#     width: 0.4006820321083069
#     height: 0.5341581702232361
#   }
#   relative_keypoints {
#     x: 0.3563041090965271
#     y: 0.5539122223854065
#   }
#   relative_keypoints {
#     x: 0.5148632526397705
#     y: 0.5844323635101318
#   }
#   relative_keypoints {
#     x: 0.49621158838272095
#     y: 0.663418710231781
#   }
#   relative_keypoints {
#     x: 0.4511571526527405
#     y: 0.7995718121528625
#   }
#   relative_keypoints {
#     x: 0.144584521651268
#     y: 0.6187312006950378
#   }
#   relative_keypoints {
#     x: 0.4915567636489868
#     y: 0.6699731945991516
#   }
# }
#
# FPS:  89.41553679542935
# 0 label_id: 0
# score: 0.761464536190033
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.14174209535121918
#     ymin: 0.4310529828071594
#     width: 0.4132988452911377
#     height: 0.5509796142578125
#   }
#   relative_keypoints {
#     x: 0.3606642186641693
#     y: 0.5554941296577454
#   }
#   relative_keypoints {
#     x: 0.5188780426979065
#     y: 0.59537672996521
#   }
#   relative_keypoints {
#     x: 0.4891827702522278
#     y: 0.6969974637031555
#   }
#   relative_keypoints {
#     x: 0.4395381212234497
#     y: 0.822151243686676
#   }
#   relative_keypoints {
#     x: 0.1534534990787506
#     y: 0.5856350064277649
#   }
#   relative_keypoints {
#     x: 0.49807336926460266
#     y: 0.6658781170845032
#   }
# }
#
# FPS:  101.80843730278168
# 0 label_id: 0
# score: 0.7258016467094421
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.14673617482185364
#     ymin: 0.4139655828475952
#     width: 0.41219624876976013
#     height: 0.5495077967643738
#   }
#   relative_keypoints {
#     x: 0.3696826994419098
#     y: 0.5404337048530579
#   }
#   relative_keypoints {
#     x: 0.5238465070724487
#     y: 0.5843045711517334
#   }
#   relative_keypoints {
#     x: 0.49441662430763245
#     y: 0.6915686726570129
#   }
#   relative_keypoints {
#     x: 0.4427792429924011
#     y: 0.8126288056373596
#   }
#   relative_keypoints {
#     x: 0.16194312274456024
#     y: 0.5576416850090027
#   }
#   relative_keypoints {
#     x: 0.5022581815719604
#     y: 0.6488136649131775
#   }
# }
#
# FPS:  95.39663838788182
# 0 label_id: 0
# score: 0.8057133555412292
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.15117692947387695
#     ymin: 0.4358707666397095
#     width: 0.40637725591659546
#     height: 0.5417463183403015
#   }
#   relative_keypoints {
#     x: 0.3671019673347473
#     y: 0.5498790144920349
#   }
#   relative_keypoints {
#     x: 0.5228314995765686
#     y: 0.5889769196510315
#   }
#   relative_keypoints {
#     x: 0.4961581826210022
#     y: 0.6835675239562988
#   }
#   relative_keypoints {
#     x: 0.4476090967655182
#     y: 0.8133578300476074
#   }
#   relative_keypoints {
#     x: 0.16035187244415283
#     y: 0.5860536694526672
#   }
#   relative_keypoints {
#     x: 0.5040479898452759
#     y: 0.6619105339050293
#   }
# }
#
# FPS:  110.41710103722424
# 0 label_id: 0
# score: 0.7726173400878906
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.16303391754627228
#     ymin: 0.4364994168281555
#     width: 0.4055786728858948
#     height: 0.5406900644302368
#   }
#   relative_keypoints {
#     x: 0.369945764541626
#     y: 0.5543412566184998
#   }
#   relative_keypoints {
#     x: 0.5270765423774719
#     y: 0.5828439593315125
#   }
#   relative_keypoints {
#     x: 0.5007228255271912
#     y: 0.6806857585906982
#   }
#   relative_keypoints {
#     x: 0.45953139662742615
#     y: 0.8102068901062012
#   }
#   relative_keypoints {
#     x: 0.17336930334568024
#     y: 0.6031352877616882
#   }
#   relative_keypoints {
#     x: 0.516399085521698
#     y: 0.6556636691093445
#   }
# }
#
# FPS:  86.85477625230374
# 0 label_id: 0
# score: 0.8007842302322388
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.18169733881950378
#     ymin: 0.4284670948982239
#     width: 0.4156316816806793
#     height: 0.5540961027145386
#   }
#   relative_keypoints {
#     x: 0.38542675971984863
#     y: 0.555411159992218
#   }
#   relative_keypoints {
#     x: 0.5451928973197937
#     y: 0.5952308177947998
#   }
#   relative_keypoints {
#     x: 0.5034137964248657
#     y: 0.7018752098083496
#   }
#   relative_keypoints {
#     x: 0.46179309487342834
#     y: 0.8234384655952454
#   }
#   relative_keypoints {
#     x: 0.20032449066638947
#     y: 0.580052375793457
#   }
#   relative_keypoints {
#     x: 0.5455027222633362
#     y: 0.6597680449485779
#   }
# }
#
# FPS:  93.4705502195084
# 0 label_id: 0
# score: 0.7854087352752686
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20606741309165955
#     ymin: 0.4266188144683838
#     width: 0.39844414591789246
#     height: 0.5311818718910217
#   }
#   relative_keypoints {
#     x: 0.39552193880081177
#     y: 0.5502737164497375
#   }
#   relative_keypoints {
#     x: 0.552977979183197
#     y: 0.5867133140563965
#   }
#   relative_keypoints {
#     x: 0.5113779902458191
#     y: 0.6848068237304688
#   }
#   relative_keypoints {
#     x: 0.47405073046684265
#     y: 0.8022494316101074
#   }
#   relative_keypoints {
#     x: 0.21972185373306274
#     y: 0.5775137543678284
#   }
#   relative_keypoints {
#     x: 0.5562964081764221
#     y: 0.6479452252388
#   }
# }
#
# FPS:  96.87285493221239
# 0 label_id: 0
# score: 0.8427658677101135
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.22241514921188354
#     ymin: 0.4450351595878601
#     width: 0.4025823473930359
#     height: 0.5367000102996826
#   }
#   relative_keypoints {
#     x: 0.4186055064201355
#     y: 0.5712990760803223
#   }
#   relative_keypoints {
#     x: 0.5770972967147827
#     y: 0.6103495955467224
#   }
#   relative_keypoints {
#     x: 0.5353296995162964
#     y: 0.7119705080986023
#   }
#   relative_keypoints {
#     x: 0.4953639507293701
#     y: 0.8293071389198303
#   }
#   relative_keypoints {
#     x: 0.23545488715171814
#     y: 0.5935570597648621
#   }
#   relative_keypoints {
#     x: 0.5757355093955994
#     y: 0.6718612313270569
#   }
# }
#
# FPS:  113.68217915706735
# 0 label_id: 0
# score: 0.8234963417053223
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.24049919843673706
#     ymin: 0.4129714369773865
#     width: 0.4142744541168213
#     height: 0.5522898435592651
#   }
#   relative_keypoints {
#     x: 0.4620302617549896
#     y: 0.5760156512260437
#   }
#   relative_keypoints {
#     x: 0.6066118478775024
#     y: 0.6052479147911072
#   }
#   relative_keypoints {
#     x: 0.578357458114624
#     y: 0.7424802184104919
#   }
#   relative_keypoints {
#     x: 0.5322012305259705
#     y: 0.8387990593910217
#   }
#   relative_keypoints {
#     x: 0.2667682468891144
#     y: 0.5637257695198059
#   }
#   relative_keypoints {
#     x: 0.5836074948310852
#     y: 0.6337778568267822
#   }
# }
#
# FPS:  91.33340591860288
# 0 label_id: 0
# score: 0.8563734889030457
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.25892946124076843
#     ymin: 0.42649102210998535
#     width: 0.4023272693157196
#     height: 0.5363498330116272
#   }
#   relative_keypoints {
#     x: 0.4819762408733368
#     y: 0.5809920430183411
#   }
#   relative_keypoints {
#     x: 0.6192538142204285
#     y: 0.6111941933631897
#   }
#   relative_keypoints {
#     x: 0.6002591848373413
#     y: 0.738658607006073
#   }
#   relative_keypoints {
#     x: 0.5533650517463684
#     y: 0.8353424668312073
#   }
#   relative_keypoints {
#     x: 0.28352147340774536
#     y: 0.5745108723640442
#   }
#   relative_keypoints {
#     x: 0.5901829600334167
#     y: 0.6418465971946716
#   }
# }
#
# FPS:  78.89071963284806
